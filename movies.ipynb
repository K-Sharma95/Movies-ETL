# %%
#Import dependencies

import json
import pandas as pd
import numpy as np

# %%
#Import the wiki data file ( combined with the kaggle data, this is the extracting step)

file_dir = 'C://Users/Kanav/documents/development/bootcamp/Movies-ETL'

# %%
f'{file_dir}filename'
# Out:
# 'C://Users/Kanav/documents/development/bootcamp/Movies-ETLfilename'

# %%
#Load the json file using the file_dir function and using this with statement

with open(f'{file_dir}/wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
# Add the json file full of movies to a list (List of dicts)

len(wiki_movies_raw)
# Out:
# 7311

# %%
wiki_movies_raw[998:999]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Getting_Even_with_Dad',
#   'year': 1994,
#   'imdb_link': 'https://www.imdb.com/title/tt0109891/',
#   'title': 'Getting Even with Dad',
#   'Directed by': 'Howard Deutch',
#   'Produced by': 'Katie Jacobs',
#   'Written by': ['Tom S. Parker', 'Jim Jennewein'],
#   'Starring': ['Macaulay Culkin',
#    'Ted Danson',
#    'Glenne Headly',
#    'Saul Rubinek',
#    'Gailard Sartain',
#    'Hector Elizondo'],
#   'Music by': 'Miles Goodman',
#   'Cinematography': 'Tim Suhrstedt',
#   'Edited by': 'Richard Halsey',
#   'Distributed by': 'Metro-Goldwyn-Mayer',
#   'Release date': ['June 17, 1994', '(', '1994-06-17', ')'],
#   'Running time': '104 minutes',
#   'Language': 'English',
#   'Budget': '$30 million',
#   'Box office': '$18,869,594'}]

# %%
#Extract two movies csv files from kaggle, which have been manually moved from downloads to movies-etl
kaggle_metadata = pd.read_csv(f'{file_dir}/movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}/ratings.csv')

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult                              belongs_to_collection budget  \
# 44382  False                                                NaN      0
# 22851  False  {'id': 430186, 'name': 'Bring It On Collection...      0
# 21960  False                                                NaN      0
# 19332  False                                                NaN      0
# 30138  False                                                NaN      0
#
#                                                   genres  \
# 44382                [{'id': 99, 'name': 'Documentary'}]
# 22851                     [{'id': 35, 'name': 'Comedy'}]
# 21960                                                 []
# 19332                      [{'id': 18, 'name': 'Drama'}]
# 30138  [{'id': 14, 'name': 'Fantasy'}, {'id': 10751, ...
#
#                             homepage      id    imdb_id original_language  \
# 44382                            NaN  458808  tt3792994                de
# ...

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 22030162  228754    96821     4.0  1451250970
# 912246      9309     1127     4.5  1146251979
# 21171826  220001     4232     4.0  1038167818
# 830367      8534     3981     2.0  1013648299
# 23169586  240470    33817     3.0  1372553540
